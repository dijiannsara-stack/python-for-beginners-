# %% [markdown]
# <a href="https://colab.research.google.com/github/dijiannsara-stack/python-for-beginners-/blob/main/course%7B%7D.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
course={}
course["Java"]="used in Mobile Applications"
course["DoNet"]="For Web base Application"
course["1"]="Php an open source for web application"
course["2"]="Android for mobile computing"
course["3"]="python is an interpeeter based"
print(course)
print(course["1"])
course["python"]="machine learning"
del course["Java"]
print(course["DoNet"])
print(course["3"])
# Out:
# {'Java': 'used in Mobile Applications', 'DoNet': 'For Web base Application', '1': 'Php an open source for web application', '2': 'Android for mobile computing', '3': 'python is an interpeeter based'}
# Php an open source for web application
# For Web base Application
# python is an interpeeter based

# %%
dict1 = {"python":1, "Java":3, "HTML":6}
var1 = dict1.pop("Java")
print(var1)
print(dict1)
# Out:
# 3
# {'python': 1, 'HTML': 6}

# %%
dict1 = {"oranges":6, "grapes":8, "apples":10, "banana":15}
var1 = dict1.pop("grapes")
var2 = dict1.pop("oranges")
print(var1)
print(var2)
print(dict1)
print(len(dict1))
# Out:
# 8
# 6
# {'apples': 10, 'banana': 15}
# 2

# %%
print("hello python")
# Out:
# hello python

# %%
dict1 = {"oranges":6, "grapes":8, "apples":10, "banana":15}
var1 = dict1.pop("banana")
var2 = dict1.pop("apples")
print(var1)
print(var2)
dict1["pineapple"]=20
print(dict1)
print(len(dict1))
# Out:
# 15
# 10
# {'oranges': 6, 'grapes': 8, 'pineapple': 20}
# 3

# %%
dict1 = {"apples":56, "oranges":12, "grapes":25}
dict2 = {"pineapples":64, "peach":25, "blueberry":25}
var1  = dict1.pop("apples")
var2  = dict2.pop("peach")
var3  = dict1.pop("grapes")
var4  = dict2.pop("blueberry")
print(var1)
print(var2)
print(var3)
print(var4)
dict1["guvava"]=80
dict2["mango"]=95
print(dict1)
print(dict2)
print(len(dict1))
print(len(dict2))
# Out:
# 56
# 25
# 25
# 25
# {'oranges': 12, 'guvava': 80}
# {'pineapples': 64, 'mango': 95}
# 2
# 2
